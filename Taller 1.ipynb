# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
df=pd.read_csv('C:/Users/abcpa/OneDrive/Escritorio/Maestria Ingenieria Y Analitica de datos/Modelado y simulacion/Datos/clasificacion.txt',sep='\t')
df.head(95)
# Out:
#      ID Caso  Clase_Vino  Alcohol  Acido_Malico  Cenizas  Alcalinidad_Cenizas  \
# 0          1           1    14.23          1.71     2.43                 15.6
# 1          2           1    13.20          1.78     2.14                 11.2
# 2          3           1    13.16          2.36     2.67                 18.6
# 3          4           1    14.37          1.95     2.50                 16.8
# 4          5           1    13.24           NaN     2.87                 21.0
# ..       ...         ...      ...           ...      ...                  ...
# 174      175           3    13.40          3.91     2.48                 23.0
# 175      176           3    13.27          4.28     2.26                 20.0
# 176      177           3    13.17          2.59     2.37                 20.0
# 177      178           3    14.13          4.10     2.74                 24.5
# 178      179           3    14.13          4.10     2.74                 24.5
#
# ...

# %% [markdown]
# ### Inspeccionando el conjunto de datos

# %%
df.shape
df.info()

# %% [markdown]
# ### Calculando estadísticas descriptivas

# %%
print('------------------------------------------------')
print('CALCULO DE ESTADISTICAS PARA LA VARIABLE CENIZAS')
print(f'El maximo de la variable cenizas es igual a {df.Cenizas.max()}')
print(f'El minimo de la variable cenizas es igual a {df.Cenizas.min()}')
print(f'La media de la variable cenizas es igual a {df.Cenizas.mean(),2}')
print(f'La desviacion estandar de la variable cenizas es igual a {df.Cenizas.std(),2}')
print(f'La varianza de la variable cenizas es igual a {df.Cenizas.var(),2}')
# Out:
# ------------------------------------------------
# CALCULO DE ESTADISTICAS PARA LA VARIABLE CENIZAS
# El maximo de la variable cenizas es igual a 3.23
# El minimo de la variable cenizas es igual a 1.36
# La media de la variable cenizas es igual a (np.float64(2.364602272727273), 2)
# La desviacion estandar de la variable cenizas es igual a (np.float64(0.2733994686909971), 2)
# La varianza de la variable cenizas es igual a (np.float64(0.0747472694805195), 2)

# %%
print('------------------------------------------------')
print('ESTADISTICAS RESUMIDAS')
df.describe(include='all')
df.head(10)
len(df) 
df.tail(5) 
df.columns 
df['Alcohol'] 
df['Alcohol'][:5] 
df['Alcohol'][5] 
df[['Prolina', 'Alcohol']][:5] 
df['Clase_Vino'].value_counts() 
#df['Clase_Vino'].unique()
# Out:
# ------------------------------------------------
# ESTADISTICAS RESUMIDAS
# Clase_Vino
# 2    71
# 1    59
# 3    49
# Name: count, dtype: int64

# %% [markdown]
# ### Cálculo de Correlaciones

# %%
df.corr(method=)
