# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn

# %%
df=pd.read_excel('C:/Users/abcpa/OneDrive/Escritorio/Maestria Ingenieria Y Analitica de datos/Modelado y simulacion/Datos/Desercion_Academica_recortados.xlsx')
df
# Out:
#            Carrera       Sexo    Origen  Localidad  Edad  Semestre  \
# 0   ADMINISTRACION   Femenino    BOGOTA       SUBA    32        10
# 1   ADMINISTRACION        NaN    BOGOTA       SUBA    30         4
# 2   ADMINISTRACION   Femenino    BOGOTA       SUBA    35         1
# 3   ADMINISTRACION   Femenino       NaN       SUBA    34         4
# 4   ADMINISTRACION   Femenino    BOGOTA    KENNEDY    37         1
# 5   ADMINISTRACION   Femenino    BOGOTA    KENNEDY    42         1
# 6              NaN  Masculino  MEDELLIN    KENNEDY    33         6
# 7   ADMINISTRACION  Masculino  MEDELLIN    KENNEDY    29         9
# 8   ADMINISTRACION   Femenino       NaN    USAQUEN    23         3
# 9   ADMINISTRACION  Masculino  MEDELLIN    USAQUEN    21         1
# 10             NaN   Femenino      CALI    USAQUEN    23         3
# 11  ADMINISTRACION   Femenino      CALI    USAQUEN    67         3
# 12             NaN   Femenino      CALI  CHAPINERO    36         8
#
# ...

# %%
df.info
